# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Importing the Dataset

# %%
df = pd.read_csv("white_wine_data_1.csv", delimiter = ',')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# # Interpreting the dataset

# %%
df.head(8)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# ...

# %%
df.shape
# Out:
# (4898, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 937

# %%
df.drop_duplicates(keep = 'first', inplace = True)

# %%
df.reset_index(drop = True, inplace=True)

# %%
df.shape
# Out:
# (3961, 12)

# %% [markdown]
# # 1. Features in Dataset

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    3961.000000       3961.000000  3961.000000     3961.000000
# mean        6.839346          0.280538     0.334332        5.914819
# std         0.866860          0.103437     0.122446        4.861646
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.600000
# 50%         6.800000          0.260000     0.320000        4.700000
# 75%         7.300000          0.330000     0.390000        8.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  3961.000000          3961.000000           3961.000000  3961.000000
# mean      0.045905            34.889169            137.193512     0.993790
# std       0.023103            17.210021             43.129065     0.002905
# ...

# %% [markdown]
# # 2. Distribution check for individual feature

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
warnings.filterwarnings('ignore')

plt.figure(figsize=(16, 10))

plt.subplot(4,3,1)
sns.kdeplot(df['fixed acidity'])

plt.subplot(4,3,2)
sns.kdeplot(df['volatile acidity'])

plt.subplot(4,3,3)
sns.kdeplot(df['citric acid'])

plt.subplot(4,3,4)
sns.kdeplot(df['residual sugar'])

plt.subplot(4,3,5)
sns.kdeplot(df['chlorides'])

plt.subplot(4,3,6)
sns.kdeplot(df['free sulfur dioxide'])

plt.subplot(4,3,7)
sns.kdeplot(df['total sulfur dioxide'])

plt.subplot(4,3,8)
sns.kdeplot(df['density'])

plt.subplot(4,3,9)
sns.kdeplot(df['pH'])

plt.subplot(4,3,10)
sns.kdeplot(df['sulphates'])

plt.subplot(4,3,11)
sns.kdeplot(df['alcohol'])

plt.suptitle("Probability density function plot for all given features", size = 19)
plt.subplots_adjust(left= 0.1, bottom = 0.1, right = 0.9, top = 0.9, wspace = 0.4, hspace = 0.6)

plt.show()

# %% [markdown]
# # 3. Checking data for imbalance

# %%
sns.countplot(df['quality'])
plt.suptitle("Plot of category count in 'Quality' column", size = 17)
# Out:
# Text(0.5, 0.98, "Plot of category count in 'Quality' column")

# %% [markdown]
# # A. Simple Linear Regression

# %% [markdown]
# # a) Finding mostly corelated input feature with output column

# %%
df.corr()['quality']
# Out:
# fixed acidity          -0.124636
# volatile acidity       -0.190678
# citric acid             0.007065
# residual sugar         -0.117339
# chlorides              -0.217739
# free sulfur dioxide     0.010507
# total sulfur dioxide   -0.183356
# density                -0.337805
# pH                      0.123829
# sulphates               0.053200
# alcohol                 0.462869
# quality                 1.000000
# Name: quality, dtype: float64

# %%
df_simple_lr = df.iloc[:,-2:]

# %% [markdown]
# # b) Parameters of the dataset

# %%
df_simple_lr.describe()
# Out:
#            alcohol      quality
# count  3961.000000  3961.000000
# mean     10.589358     5.854835
# std       1.217076     0.890683
# min       8.000000     3.000000
# 25%       9.500000     5.000000
# 50%      10.400000     6.000000
# 75%      11.400000     6.000000
# max      14.200000     9.000000

# %% [markdown]
# # c) PDF Plot for 'alcohol' column

# %%
sns.kdeplot(df['alcohol'])
plt.suptitle("PDF plot 'alcohol' column", size = 14)
# Out:
# Text(0.5, 0.98, "PDF plot 'alcohol' column")

# %% [markdown]
# # d) Outliers checking

# %%
sns.boxplot(df_simple_lr['alcohol'])
plt.suptitle("Box plot for 'alcohol' column", size = 14)
# Out:
# Text(0.5, 0.98, "Box plot for 'alcohol' column")

# %% [markdown]
# # e) Splitting the Dataset

# %%
from sklearn.model_selection import train_test_split
X = df_simple_lr['alcohol']
y = df_simple_lr['quality']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 13, test_size = 0.2)

# %%
X_train
# Out:
# 3652    12.75
# 3445    12.10
# 1787     9.60
# 405      9.70
# 774     10.70
#         ...
# 2790    10.20
# 3600    12.80
# 74       8.70
# 2224     9.20
# 338      9.20
# Name: alcohol, Length: 3168, dtype: float64

# %%
X_train.shape
# Out:
# (3168,)

# %%
X_test
# Out:
# 1032    10.00
# 233      9.80
# 3410    10.10
# 3386     9.80
# 1191    11.40
#         ...
# 1535    12.30
# 3568     9.80
# 3908    11.10
# 3611    10.55
# 2961    10.80
# Name: alcohol, Length: 793, dtype: float64

# %%
X_test.shape
# Out:
# (793,)

# %%
y_test = y_test.to_numpy()

# %%
X_train = X_train.to_numpy().reshape(-1, 1)
X_test = X_test.to_numpy().reshape(-1, 1)

# %% [markdown]
# # f) Training & predicting the model

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
pred_slr = lr.predict(X_test)

# %% [markdown]
# # 2. Multiple Linear Regression

# %% [markdown]
# # a) Checking for Multicolinearity

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df.corr(), annot = True)
plt.suptitle("Correlation of features- Heatmap", size = 17)
# Out:
# Text(0.5, 0.98, 'Correlation of features- Heatmap')

# %% [markdown]
# # b) Finding outliers with Boxplot

# %%
warnings.filterwarnings('ignore')

plt.figure(figsize=(16, 10))

plt.subplot(4,3,1)
sns.boxplot(df['fixed acidity'])

plt.subplot(4,3,2)
sns.boxplot(df['volatile acidity'])

plt.subplot(4,3,3)
sns.boxplot(df['citric acid'])

plt.subplot(4,3,4)
sns.boxplot(df['residual sugar'])

plt.subplot(4,3,5)
sns.boxplot(df['chlorides'])

plt.subplot(4,3,6)
sns.boxplot(df['free sulfur dioxide'])

plt.subplot(4,3,7)
sns.boxplot(df['total sulfur dioxide'])

plt.subplot(4,3,8)
sns.boxplot(df['density'])

plt.subplot(4,3,9)
sns.boxplot(df['pH'])

plt.subplot(4,3,10)
sns.boxplot(df['sulphates'])

plt.subplot(4,3,11)
sns.boxplot(df['alcohol'])

plt.suptitle("Boxplot for all given features", size = 19)
plt.subplots_adjust(left= 0.1, bottom = 0.1, right = 0.9, top = 0.9, wspace = 0.4, hspace = 0.6)

plt.show()

# %% [markdown]
# # c) Splitting the dataset into train & test set

# %%
x_mlr = df.drop(columns=['quality'])
y_mlr = df['quality']
X_train_mlr, X_test_mlr, y_train_mlr, y_test_mlr = train_test_split(x_mlr, y_mlr, random_state = 13, test_size = 0.2)

# %%
X_train_mlr
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3652            5.8             0.280         0.30             3.9      0.026
# 3445            5.7             0.220         0.29             3.5      0.040
# 1787            7.2             0.115         0.30             6.8      0.056
# 405             6.0             0.160         0.37             1.5      0.025
# 774             7.9             0.280         0.41             2.0      0.044
# ...             ...               ...          ...             ...        ...
# 2790            5.8             0.150         0.32             1.2      0.037
# 3600            5.9             0.220         0.45            22.6      0.120
# 74              7.1             0.440         0.62            11.8      0.044
# 2224            6.6             0.240         0.38             8.0      0.042
# 338             6.1             0.350         0.07             1.4      0.069
#
# ...

# %%
X_train_mlr.shape
# Out:
# (3168, 11)

# %%
X_test_mlr
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1032            7.6              0.28         0.39             1.2      0.038
# 233             6.7              0.20         0.41             9.1      0.044
# 3410            5.2              0.20         0.27             3.2      0.047
# 3386            6.3              0.30         0.48             7.4      0.053
# 1191            7.1              0.19         0.28             3.6      0.033
# ...             ...               ...          ...             ...        ...
# 1535            6.0              0.26         0.29             1.0      0.032
# 3568            7.2              0.47         0.16             5.9      0.048
# 3908            5.7              0.22         0.25             1.1      0.050
# 3611            6.8              0.31         0.25            10.5      0.043
# 2961            6.6              0.30         0.25             8.0      0.036
#
# ...

# %%
X_test_mlr.shape
# Out:
# (793, 11)

# %% [markdown]
# # d)  Training the model & predicting

# %%
mlr = LinearRegression()
mlr.fit(X_train_mlr, y_train_mlr)
# Out:
# LinearRegression()

# %%
pred_mlr = mlr.predict(X_test_mlr)

# %% [markdown]
# # 3. Diagnostic Plots

# %% [markdown]
# # i) SLR

# %% [markdown]
# # a) Checking homoscedasticity of residues

# %%
res_lr = y_test - pred_slr

# %%
plt.title("Residual plot of SLR", size = 16)
sns.scatterplot(pred_slr, res_lr)
# Out:
# <AxesSubplot:title={'center':'Residual plot of SLR'}>

# %% [markdown]
# # b) Checking Normality of residues

# %%
import scipy as sp

plt.figure(figsize=(6,4))
sns.kdeplot(res_lr)
plt.title("PDF plot of residuals in SLR", size = 16)

fig, ax = plt.subplots(figsize=(6,4))
sp.stats.probplot(res_lr, plot = ax, fit=True)
plt.title("Q-Q plot for SLR", size = 16)
plt.show()

# %% [markdown]
# # 4. RESULTS - Interpreting the dataset

# %% [markdown]
# # ii) Performance of models

# %% [markdown]
# # SLR Model

# %%
from sklearn.metrics import r2_score, mean_absolute_error

r2_score_slr = round(r2_score(y_test, pred_slr),3)
mean_slr = round(mean_absolute_error(y_test, pred_slr),3)
adj_r2_slr = round(1-((1-r2_score_slr)*(793-1)/(793-1-1)),3)

print("R2 score = ", r2_score_slr)
print("Adjusted R2 score = ", adj_r2_slr)
print("Mean Absolute Error = ", mean_slr)
# Out:
# R2 score =  0.225
# Adjusted R2 score =  0.224
# Mean Absolute Error =  0.617

# %% [markdown]
# # MLR Model

# %%
r2_score_mlr = round(r2_score(y_test_mlr, pred_mlr),3)
mean_mlr = round(mean_absolute_error(y_test_mlr, pred_mlr),3)
adj_r2_mlr = round(1-((1-r2_score_mlr)*(793-1)/(793-1-1)),3)

print("R2 score = ", r2_score_mlr)
print("Adjusted R2 score = ", adj_r2_mlr)
print("Mean Absolute Error = ", mean_mlr)
# Out:
# R2 score =  0.304
# Adjusted R2 score =  0.303
# Mean Absolute Error =  0.566

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
print(f"Intercept of the fitted hyperplane = {mlr.intercept_:.2f}")
for index, column in enumerate(X_train_mlr.columns):
    print(f"Coefficient of column: {column} = {mlr.coef_[index]:.2f}")
# Out:
# Intercept of the fitted hyperplane = 132.52
# Coefficient of column: fixed acidity = 0.05
# Coefficient of column: volatile acidity = -1.57
# Coefficient of column: citric acid = 0.18
# Coefficient of column: residual sugar = 0.07
# Coefficient of column: chlorides = -0.27
# Coefficient of column: free sulfur dioxide = 0.01
# Coefficient of column: total sulfur dioxide = -0.00
# Coefficient of column: density = -133.32
# Coefficient of column: pH = 0.84
# Coefficient of column: sulphates = 0.67
# Coefficient of column: alcohol = 0.22
